# %% [markdown]
# <a href="https://colab.research.google.com/github/samir98441/GRIP-Spark-Foundation/blob/main/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task - 03**
#
# **Name: SAMEER KAYASTHA**
#
# **TOPIC:For the given ‘Iris’ dataset, creating the Decision Tree classifier and visualizing it graphically.**

# %% [markdown]
# **Importing Packages**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Loading dataset**

# %%
df=pd.read_csv('Iris.csv')
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# **Summerizing data**

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# **Dropping id**

# %%
df=df.drop("Id",axis=1)

# %% [markdown]
# **Checking null values**

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# **Data Visualization**

# %%
##Checking relation of petal and sepal using pairplot
sns.pairplot( df , hue = 'Species')
plt.show()

# %% [markdown]
# We can see species Iris-setosa has attributes different from the other 2 species Iris-versicolor and Iris-virginica.

# %% [markdown]
# **Preparing dataset for trainig**

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %% [markdown]
# **Train test split**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# **Applying Decision Tree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score
classifier=DecisionTreeClassifier()
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred=classifier.predict(x_test)
print('accuracy: ',accuracy_score(y_pred,y_test))
# Out:
# accuracy:  1.0

# %% [markdown]
# **Visualizing decision tree**

# %%
plt.figure(figsize =( 50,30))
plt.style.use('grayscale') 
plot_tree(classifier,rounded=True,filled=True,feature_names=x.columns);

# %% [markdown]
# **Now we can feed any new/test data to this classifer and it would be able to predict the right class accordingly**
